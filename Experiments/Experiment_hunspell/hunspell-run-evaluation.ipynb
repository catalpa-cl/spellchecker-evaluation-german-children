# %% [markdown]
# # Spelling correction with hunspell on litkey data set
#
# Contents:
# 1. Preparation
#     - Imports
#     - Load data set
#         - **Types**
#         - **Token**
#     - Preprocessing
# 2. Running hunspell on litkey data set
#     - **Types**
#     - **Tokens**
# 3. Evaluation

# %% [markdown]
# ## 1 - Preparation

# %%
# IMPORTS
#%autoreload 2

import re
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
from tqdm.notebook import tqdm # A fast, extensible progress bar

import sys
# TODO: Relativen Pfad einbauen
# --> Issue aufmachen oder elegantere Ordnerstruktur

sys.path.insert(0, '/Users/lisaprepens/_Programmierung/bodu-spell/spelling_correction')
#sys.path.insert(0, '../../')
# sys.path

from Lisa import litkey_2
#import Lisa.litkey_2

# %%
# Configuration
# Set figure size for sns plot
# %config InlineBackend.figure_format = 'retina'
mpl.rc('figure', figsize=(8, 6), dpi=100)
sns.set()
sns.set_style('darkgrid')

# Set tqdm on pandas
tqdm.pandas(desc="Progress so far...")

# Do not truncate columns of DataFrame
pd.set_option('display.max_rows', None)
# Out:
# /Users/lisaprepens/.conda/envs/bodu-spell_Env/lib/python3.8/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
#tqdm.pandas(desc='my bar')
#import numpy as np
#tqdm.pandas()
#df = pd.DataFrame(np.random.randint(0, 100, (100000, 6)))
#df.progress_apply(lambda x: x**2)

# %%
# LOAD LITKEY DATA SET
# It was the wrong path; Go two levels up
data_error_types = litkey_2.load(litkey_data_path ='../../litkey-data/')

data_error_token = litkey_2.load(litkey_data_path ='../../litkey-data/', toss_duplicates=False)

# %%
# PREPROCESSING

#Hunspell treats words with some punctuation marks as two words (e.g. Seil=bahn), which would destroy the indices; 
#therefore, "=" is replaced with "-" and the others are deleted prior to analysis with Hunspell

data_error_types['unchanged_original'] = data_error_types['original']
data_error_types['original'] = data_error_types['original'].str.replace("=", '-')
data_error_types['original'] = data_error_types['original'].str.replace('"', '')
data_error_types['original'] = data_error_types['original'].str.replace(":", '')
data_error_types['original'] = data_error_types['original'].str.replace(",", '')
data_error_types['original'] = data_error_types['original'].str.replace("'", '')

data_error_token['unchanged_original'] = data_error_token['original']
data_error_token['original'] = data_error_token['original'].str.replace("=", '-')
data_error_token['original'] = data_error_token['original'].str.replace('"', '')
data_error_token['original'] = data_error_token['original'].str.replace(":", '')
data_error_token['original'] = data_error_token['original'].str.replace(",", '')
data_error_token['original'] = data_error_token['original'].str.replace("'", '')

# %%
display(data_error_types.head(100))
display(data_error_token.head(100))
# Out:
#          original       corrected              filename  freq_ori  freq_cor  \
# 0            belt           bellt  01-005-2-III-Eis.csv        91       138
# 1            kukt           kuckt  01-005-2-III-Eis.csv        73       152
# 2             dan            dann  01-005-2-III-Eis.csv       627       651
# 3        gekricht        gekriegt  01-005-2-III-Eis.csv         2        15
# 4           leken          lecken  01-005-2-III-Eis.csv        14        17
# 5            felt           fällt  01-005-2-III-Eis.csv        93       198
# 6           wolte          wollte  01-005-2-III-Eis.csv       173       201
# 7            lekt           leckt  01-005-2-III-Eis.csv        20        42
# 8             fom             vom  01-005-2-III-Eis.csv        13        16
# 9           gawen          kaufen  01-006-2-III-Eis.csv         1         6
# 10            din             ein  01-006-2-III-Eis.csv         2        26
# 11           Keld            Geld  01-006-2-III-Eis.csv         1         5
# 12            man            Mann  01-006-2-III-Eis.csv        79       132
# 13           gien           gehen  01-006-2-III-Eis.csv         1        78
# 14        nahaise       nachhause  01-006-2-III-Eis.csv         1        10
# 15           esen           essen  01-006-2-III-Eis.csv        22        14
# 16            aba            aber  01-006-2-III-Eis.csv        21        60
# 17         gieben           geben  01-006-2-III-Eis.csv         1         3
# 18          wollt          wollte  01-006-2-III-Eis.csv         2       201
# 19           feid           fällt  01-006-2-III-Eis.csv         1       198
# 20            gen           gehen  01-012-2-III-Eis.csv        31        78
# 21            wil            will  01-012-2-III-Eis.csv        95       157
# 22           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 23            ter             der  01-012-2-III-Eis.csv         1         9
# 24             ap              ab  01-012-2-III-Eis.csv        26        30
# 25            ale            alle  01-012-2-III-Eis.csv        34        39
# 26        frölich        fröhlich  01-012-2-III-Eis.csv        51        92
# 27          siend            sind  01-025-2-III-Eis.csv        16        66
# 28  weitagegangen  weitergegangen  01-025-2-III-Eis.csv         1         1
# 29       natürlig       natürlich  01-025-2-III-Eis.csv         1        19
# 30           üder            über  01-025-2-III-Eis.csv         8        35
# 31            ier             ihr  01-025-2-III-Eis.csv         7        40
# 32         runder          runter  01-025-2-III-Eis.csv        18        60
# 33         harden           haben  01-025-2-III-Eis.csv         2        19
# 34        schneel         schnell  01-025-2-III-Eis.csv         1        76
# 35          haten          hatten  01-025-2-III-Eis.csv        53        55
# 36          arder            aber  01-025-2-III-Eis.csv         3        60
# 37          gugel           Kugel  01-025-2-III-Eis.csv         1         3
# 38           hate           hatte  01-025-2-III-Eis.csv       400       427
# 39           geld            gelb  01-025-2-III-Eis.csv         1         1
# 40   eisferkeufer    Eisverkäufer  01-026-2-III-Eis.csv         1         4
# 41             in             ihn  01-026-2-III-Eis.csv       261       270
# 42            Dan            Dann  01-026-2-III-Eis.csv       188       197
# 43             ir             ihr  01-026-2-III-Eis.csv        27        40
# 44          fenkt           fängt  01-026-2-III-Eis.csv         1        29
# 45            get            geht  01-026-2-III-Eis.csv        56        85
# 46        Stolpat        stolpert  01-026-2-III-Eis.csv         2        27
# 47            üba            über  01-026-2-III-Eis.csv         7        35
# 48          fellt           fällt  01-026-2-III-Eis.csv         9       198
# 49           hinn             hin  01-026-2-III-Eis.csv         2        17
# 50            ide            Idee  01-026-2-III-Eis.csv        12        34
# 51          giebt            gibt  01-026-2-III-Eis.csv        16        42
# 52       glüklieg       glücklich  01-026-2-III-Eis.csv         1       163
# 53        bekomen        bekommen  01-028-2-III-Eis.csv        19        31
# 54          kabut          kaputt  01-028-2-III-Eis.csv         4       126
# 55     hingefalen     hingefallen  01-028-2-III-Eis.csv         5        11
# 56            rhr             ihr  01-028-2-III-Eis.csv         1        40
# 57         Teielt           teilt  01-028-2-III-Eis.csv         1         6
# 58        möschde          möchte  01-029-2-III-Eis.csv         1        14
# 59           past           passt  01-029-2-III-Eis.csv         2         3
# 60           veil            weil  01-029-2-III-Eis.csv         4        82
# 61        möschte          möchte  01-029-2-III-Eis.csv         2        14
# 62             on             und  01-029-2-III-Eis.csv         2       106
# 63  runtergefalen  runtergefallen  01-029-2-III-Eis.csv        12        28
# 64            ern              er  01-029-2-III-Eis.csv         2        14
# 65          fählt           fällt  01-029-2-III-Eis.csv         5       198
# 66          vegen           wegen  01-029-2-III-Eis.csv         1         5
# 67       glüglich       glücklich  01-029-2-III-Eis.csv        18       163
# 68          veint           weint  01-029-2-III-Eis.csv         1        67
# 69            hie            hier  01-029-2-III-Eis.csv         1        55
# 70          krikt          kriegt  01-037-2-III-Eis.csv         8        51
# 71        bischen        bisschen  01-037-2-III-Eis.csv        20        57
# 72             au             auf  01-037-2-III-Eis.csv         6        17
# 73        schlekt        schleckt  01-037-2-III-Eis.csv         2         4
# 74           ales           alles  01-037-2-III-Eis.csv        35        37
# 75     TroPfschen       Tröpfchen  01-045-2-III-Eis.csv         1         2
# 76      gestolPat      gestolpert  01-045-2-III-Eis.csv         1        14
# 77        wegetan        wehgetan  01-045-2-III-Eis.csv        11        17
# 78      Glöklesch       glücklich  01-045-2-III-Eis.csv         1       163
# 79           rich           riech  01-045-2-III-Eis.csv         2         2
# 80       Spatzirn       spazieren  01-049-2-III-Eis.csv         1       116
# 81           falt           fallt  01-049-2-III-Eis.csv         9        11
# 82          Giebt            gibt  01-049-2-III-Eis.csv         1        42
# 83           eien            eine  01-049-2-III-Eis.csv         2         9
# 84       Nachause       nachhause  01-049-2-III-Eis.csv         1        10
# 85           Lekt           leckt  01-049-2-III-Eis.csv         4        42
# 86          siech            sich  01-054-2-III-Eis.csv        24        55
# 87       gehmergt         gemerkt  01-054-2-III-Eis.csv         1        10
# 88            das            dass  01-054-2-III-Eis.csv       985      1017
# 89     gehttropft        getropft  01-054-2-III-Eis.csv         1         2
# 90        gefalen        gefallen  01-054-2-III-Eis.csv        50        69
# 91         ristig         richtig  01-054-2-III-Eis.csv         1         9
# 92       glüglist       glücklich  01-054-2-III-Eis.csv         1       163
# 93             is             iss  01-054-2-III-Eis.csv        19         2
# 94         schnel         schnell  01-054-2-III-Eis.csv        60        76
# 95        Hinther       hinterher  01-054-2-III-Eis.csv         1        38
# 96           sint            sind  01-057-2-III-Eis.csv        20        66
# 97              i              in  01-057-2-III-Eis.csv         2        21
# 98      eiswargen        Eiswagen  01-057-2-III-Eis.csv         1         3
# 99             si             sie  01-057-2-III-Eis.csv        51        86
#
#     freq_tup
# 0         91
# 1         73
# 2        621
# 3          2
# 4         14
# 5         90
# 6        173
# 7         19
# 8         13
# 9          1
# 10         1
# 11         1
# 12        79
# 13         1
# 14         1
# 15        12
# 16        21
# 17         1
# 18         2
# 19         1
# 20        31
# 21        95
# 22        18
# 23         1
# 24        26
# 25        33
# 26        51
# 27        16
# 28         1
# 29         1
# 30         8
# 31         6
# 32        18
# 33         2
# 34         1
# 35        53
# 36         3
# 37         1
# 38       400
# 39         1
# 40         1
# 41       260
# 42       185
# 43        27
# 44         1
# 45        56
# 46         2
# 47         7
# 48         9
# 49         2
# 50        12
# 51        15
# 52         1
# 53        18
# 54         4
# 55         5
# 56         1
# 57         1
# 58         1
# 59         2
# 60         4
# 61         2
# 62         2
# 63        12
# 64         2
# 65         5
# 66         1
# 67        18
# 68         1
# 69         1
# 70         8
# 71        20
# 72         1
# 73         1
# 74        34
# 75         1
# 76         1
# 77        11
# 78         1
# 79         2
# 80         1
# 81         9
# 82         1
# 83         1
# 84         1
# 85         4
# 86        24
# 87         1
# 88       981
# 89         1
# 90        50
# 91         1
# 92         1
# 93         1
# 94        60
# 95         1
# 96        20
# 97         1
# 98         1
# 99        46
#          original       corrected              filename  freq_ori  freq_cor  \
# 0            belt           bellt  01-005-2-III-Eis.csv        91       138
# 1            kukt           kuckt  01-005-2-III-Eis.csv        73       152
# 2             dan            dann  01-005-2-III-Eis.csv       627       651
# 3        gekricht        gekriegt  01-005-2-III-Eis.csv         2        15
# 4           leken          lecken  01-005-2-III-Eis.csv        14        17
# 5            felt           fällt  01-005-2-III-Eis.csv        93       198
# 6           wolte          wollte  01-005-2-III-Eis.csv       173       201
# 7            lekt           leckt  01-005-2-III-Eis.csv        20        42
# 8             fom             vom  01-005-2-III-Eis.csv        13        16
# 9             dan            dann  01-005-2-III-Eis.csv       627       651
# 10            dan            dann  01-005-2-III-Eis.csv       627       651
# 11          leken          lecken  01-005-2-III-Eis.csv        14        17
# 12          gawen          kaufen  01-006-2-III-Eis.csv         1         6
# 13            din             ein  01-006-2-III-Eis.csv         2        26
# 14           Keld            Geld  01-006-2-III-Eis.csv         1         5
# 15            man            Mann  01-006-2-III-Eis.csv        79       132
# 16            man            Mann  01-006-2-III-Eis.csv        79       132
# 17           gien           gehen  01-006-2-III-Eis.csv         1        78
# 18        nahaise       nachhause  01-006-2-III-Eis.csv         1        10
# 19           esen           essen  01-006-2-III-Eis.csv        22        14
# 20           esen           essen  01-006-2-III-Eis.csv        22        14
# 21            aba            aber  01-006-2-III-Eis.csv        21        60
# 22         gieben           geben  01-006-2-III-Eis.csv         1         3
# 23          wollt          wollte  01-006-2-III-Eis.csv         2       201
# 24           feid           fällt  01-006-2-III-Eis.csv         1       198
# 25            gen           gehen  01-012-2-III-Eis.csv        31        78
# 26            wil            will  01-012-2-III-Eis.csv        95       157
# 27           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 28           felt           fällt  01-012-2-III-Eis.csv        93       198
# 29            ter             der  01-012-2-III-Eis.csv         1         9
# 30           felt           fällt  01-012-2-III-Eis.csv        93       198
# 31           lekt           leckt  01-012-2-III-Eis.csv        20        42
# 32           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 33             ap              ab  01-012-2-III-Eis.csv        26        30
# 34            ale            alle  01-012-2-III-Eis.csv        34        39
# 35        frölich        fröhlich  01-012-2-III-Eis.csv        51        92
# 36          siend            sind  01-025-2-III-Eis.csv        16        66
# 37  weitagegangen  weitergegangen  01-025-2-III-Eis.csv         1         1
# 38       natürlig       natürlich  01-025-2-III-Eis.csv         1        19
# 39           üder            über  01-025-2-III-Eis.csv         8        35
# 40            ier             ihr  01-025-2-III-Eis.csv         7        40
# 41         runder          runter  01-025-2-III-Eis.csv        18        60
# 42         harden           haben  01-025-2-III-Eis.csv         2        19
# 43        schneel         schnell  01-025-2-III-Eis.csv         1        76
# 44          haten          hatten  01-025-2-III-Eis.csv        53        55
# 45          arder            aber  01-025-2-III-Eis.csv         3        60
# 46          haten          hatten  01-025-2-III-Eis.csv        53        55
# 47          gugel           Kugel  01-025-2-III-Eis.csv         1         3
# 48           hate           hatte  01-025-2-III-Eis.csv       400       427
# 49           hate           hatte  01-025-2-III-Eis.csv       400       427
# 50           geld            gelb  01-025-2-III-Eis.csv         1         1
# 51   eisferkeufer    Eisverkäufer  01-026-2-III-Eis.csv         1         4
# 52             in             ihn  01-026-2-III-Eis.csv       261       270
# 53            Dan            Dann  01-026-2-III-Eis.csv       188       197
# 54            gen           gehen  01-026-2-III-Eis.csv        31        78
# 55           esen           essen  01-026-2-III-Eis.csv        22        14
# 56             ir             ihr  01-026-2-III-Eis.csv        27        40
# 57          fenkt           fängt  01-026-2-III-Eis.csv         1        29
# 58            get            geht  01-026-2-III-Eis.csv        56        85
# 59        Stolpat        stolpert  01-026-2-III-Eis.csv         2        27
# 60            üba            über  01-026-2-III-Eis.csv         7        35
# 61          fellt           fällt  01-026-2-III-Eis.csv         9       198
# 62             ir             ihr  01-026-2-III-Eis.csv        27        40
# 63          fellt           fällt  01-026-2-III-Eis.csv         9       198
# 64           hinn             hin  01-026-2-III-Eis.csv         2        17
# 65             ir             ihr  01-026-2-III-Eis.csv        27        40
# 66           lekt           leckt  01-026-2-III-Eis.csv        20        42
# 67            ide            Idee  01-026-2-III-Eis.csv        12        34
# 68          giebt            gibt  01-026-2-III-Eis.csv        16        42
# 69            dan            dann  01-026-2-III-Eis.csv       627       651
# 70            gen           gehen  01-026-2-III-Eis.csv        31        78
# 71       glüklieg       glücklich  01-026-2-III-Eis.csv         1       163
# 72        bekomen        bekommen  01-028-2-III-Eis.csv        19        31
# 73          kabut          kaputt  01-028-2-III-Eis.csv         4       126
# 74     hingefalen     hingefallen  01-028-2-III-Eis.csv         5        11
# 75            rhr             ihr  01-028-2-III-Eis.csv         1        40
# 76         Teielt           teilt  01-028-2-III-Eis.csv         1         6
# 77        möschde          möchte  01-029-2-III-Eis.csv         1        14
# 78            aba            aber  01-029-2-III-Eis.csv        21        60
# 79            aba            aber  01-029-2-III-Eis.csv        21        60
# 80           past           passt  01-029-2-III-Eis.csv         2         3
# 81           veil            weil  01-029-2-III-Eis.csv         4        82
# 82        möschte          möchte  01-029-2-III-Eis.csv         2        14
# 83             on             und  01-029-2-III-Eis.csv         2       106
# 84            dan            dann  01-029-2-III-Eis.csv       627       651
# 85  runtergefalen  runtergefallen  01-029-2-III-Eis.csv        12        28
# 86            ern              er  01-029-2-III-Eis.csv         2        14
# 87          fählt           fällt  01-029-2-III-Eis.csv         5       198
# 88          vegen           wegen  01-029-2-III-Eis.csv         1         5
# 89       glüglich       glücklich  01-029-2-III-Eis.csv        18       163
# 90          veint           weint  01-029-2-III-Eis.csv         1        67
# 91            ern              er  01-029-2-III-Eis.csv         2        14
# 92           veil            weil  01-029-2-III-Eis.csv         4        82
# 93            hie            hier  01-029-2-III-Eis.csv         1        55
# 94          krikt          kriegt  01-037-2-III-Eis.csv         8        51
# 95        bischen        bisschen  01-037-2-III-Eis.csv        20        57
# 96           felt           fällt  01-037-2-III-Eis.csv        93       198
# 97           felt           fällt  01-037-2-III-Eis.csv        93       198
# 98             au             auf  01-037-2-III-Eis.csv         6        17
# 99        schlekt        schleckt  01-037-2-III-Eis.csv         2         4
#
#     freq_tup
# 0         91
# 1         73
# 2        621
# 3          2
# 4         14
# 5         90
# 6        173
# 7         19
# 8         13
# 9        621
# 10       621
# 11        14
# 12         1
# 13         1
# 14         1
# 15        79
# 16        79
# 17         1
# 18         1
# 19        12
# 20        12
# 21        21
# 22         1
# 23         2
# 24         1
# 25        31
# 26        95
# 27        18
# 28        90
# 29         1
# 30        90
# 31        19
# 32        18
# 33        26
# 34        33
# 35        51
# 36        16
# 37         1
# 38         1
# 39         8
# 40         6
# 41        18
# 42         2
# 43         1
# 44        53
# 45         3
# 46        53
# 47         1
# 48       400
# 49       400
# 50         1
# 51         1
# 52       260
# 53       185
# 54        31
# 55        12
# 56        27
# 57         1
# 58        56
# 59         2
# 60         7
# 61         9
# 62        27
# 63         9
# 64         2
# 65        27
# 66        19
# 67        12
# 68        15
# 69       621
# 70        31
# 71         1
# 72        18
# 73         4
# 74         5
# 75         1
# 76         1
# 77         1
# 78        21
# 79        21
# 80         2
# 81         4
# 82         2
# 83         2
# 84       621
# 85        12
# 86         2
# 87         5
# 88         1
# 89        18
# 90         1
# 91         2
# 92         4
# 93         1
# 94         8
# 95        20
# 96        90
# 97        90
# 98         1
# 99         1

# %% [markdown]
# ## 2 - Running hunspell on litkey data set
# ###  a) Types

# %%
# Create csv-file containing 'original'-column (misspelled) data to be analysed with hunspell
data_error_types.original.to_csv('original_hun.csv', header=False, index=False)

# The beforementioned csv-file is input to hunspell analysis with german dictionary;
# Output of analysis is put to a txt file
# Build a file 'hunspell.txt' with corrections for each word
# !cat original_hun.csv | hunspell -d de_DE > output_hun.txt
#!type original_hun.csv | hunspell -d de_DE > hunspell.txt



# Build a list (suggestions-column) of top correction suggestions from hunspell for each word, '' for correct, '?' for unrecognized
# Reading in all the lines
hs = []
with open('output_hun.txt') as f:
    next(f)
    for index, l in enumerate([l for l in [line.strip() for line in f] if l]):
        # Words recognized as correct
        # (* = dictionary stem (e. g. "man"), + = affixed forms of the following dictionary stem (e. g. "wollt" - wollen))
        # Append nothing to hs
        
        # TODO: Why minus flag?
        if re.match(r'\+|\*|-', l):
            hs.append('')
            
        # Words not recognized/rejected words (# = without suggestions)
        # Append '?' to hs
        elif re.match('#', l):
            hs.append('?')
            
        # Words not recognized/rejected words (& = with suggestions)
        # Append suggested words to hs
        else:
            hs.append(l.split(': ')[1].split(', '))

            
# Add hunspell's corrections as column to data
print(data_error_types.shape[0])
print(len(hs))

data_error_types['suggestions'] = hs

data_error_types.head(40)    # Print excerpt from DataFrame
# Out:
# 9484
# 9484
#          original       corrected              filename  freq_ori  freq_cor  \
# 0            belt           bellt  01-005-2-III-Eis.csv        91       138
# 1            kukt           kuckt  01-005-2-III-Eis.csv        73       152
# 2             dan            dann  01-005-2-III-Eis.csv       627       651
# 3        gekricht        gekriegt  01-005-2-III-Eis.csv         2        15
# 4           leken          lecken  01-005-2-III-Eis.csv        14        17
# 5            felt           fällt  01-005-2-III-Eis.csv        93       198
# 6           wolte          wollte  01-005-2-III-Eis.csv       173       201
# 7            lekt           leckt  01-005-2-III-Eis.csv        20        42
# 8             fom             vom  01-005-2-III-Eis.csv        13        16
# 9           gawen          kaufen  01-006-2-III-Eis.csv         1         6
# 10            din             ein  01-006-2-III-Eis.csv         2        26
# 11           Keld            Geld  01-006-2-III-Eis.csv         1         5
# 12            man            Mann  01-006-2-III-Eis.csv        79       132
# 13           gien           gehen  01-006-2-III-Eis.csv         1        78
# 14        nahaise       nachhause  01-006-2-III-Eis.csv         1        10
# 15           esen           essen  01-006-2-III-Eis.csv        22        14
# 16            aba            aber  01-006-2-III-Eis.csv        21        60
# 17         gieben           geben  01-006-2-III-Eis.csv         1         3
# 18          wollt          wollte  01-006-2-III-Eis.csv         2       201
# 19           feid           fällt  01-006-2-III-Eis.csv         1       198
# 20            gen           gehen  01-012-2-III-Eis.csv        31        78
# 21            wil            will  01-012-2-III-Eis.csv        95       157
# 22           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 23            ter             der  01-012-2-III-Eis.csv         1         9
# 24             ap              ab  01-012-2-III-Eis.csv        26        30
# 25            ale            alle  01-012-2-III-Eis.csv        34        39
# 26        frölich        fröhlich  01-012-2-III-Eis.csv        51        92
# 27          siend            sind  01-025-2-III-Eis.csv        16        66
# 28  weitagegangen  weitergegangen  01-025-2-III-Eis.csv         1         1
# 29       natürlig       natürlich  01-025-2-III-Eis.csv         1        19
# 30           üder            über  01-025-2-III-Eis.csv         8        35
# 31            ier             ihr  01-025-2-III-Eis.csv         7        40
# 32         runder          runter  01-025-2-III-Eis.csv        18        60
# 33         harden           haben  01-025-2-III-Eis.csv         2        19
# 34        schneel         schnell  01-025-2-III-Eis.csv         1        76
# 35          haten          hatten  01-025-2-III-Eis.csv        53        55
# 36          arder            aber  01-025-2-III-Eis.csv         3        60
# 37          gugel           Kugel  01-025-2-III-Eis.csv         1         3
# 38           hate           hatte  01-025-2-III-Eis.csv       400       427
# 39           geld            gelb  01-025-2-III-Eis.csv         1         1
#
#     freq_tup unchanged_original  \
# 0         91               belt
# 1         73               kukt
# 2        621                dan
# 3          2           gekricht
# 4         14              leken
# 5         90               felt
# 6        173              wolte
# 7         19               lekt
# 8         13                fom
# 9          1              gawen
# 10         1                din
# 11         1               Keld
# 12        79                man
# 13         1               gien
# 14         1            nahaise
# 15        12               esen
# 16        21                aba
# 17         1             gieben
# 18         2              wollt
# 19         1               feid
# 20        31                gen
# 21        95                wil
# 22        18               gipt
# 23         1                ter
# 24        26                 ap
# 25        33                ale
# 26        51            frölich
# 27        16              siend
# 28         1      weitagegangen
# 29         1           natürlig
# 30         8               üder
# 31         6                ier
# 32        18             runder
# 33         2             harden
# 34         1            schneel
# 35        53              haten
# 36         3              arder
# 37         1              gugel
# 38       400               hate
# 39         1               geld
#
#                                           suggestions
# 0    [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                                        [kurt, bukt]
# 2   [da, an, dann, dran, dank, den, das, dar, ran,...
# 3      [gekracht, gekreischt, gerichtet, gerichtlich]
# 4   [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5   [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6                       [wollte, walte, wolle, holte]
# 7              [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                         [vom, Rom, Tom, Dom, fromm]
# 9                               [wagen, garen, gaben]
# 10  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 11                          [Geld, Held, Feld, Kelle]
# 12
# 13                          [gen, gier, Wien, gießen]
# 14                                        [nachweise]
# 15  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
# 16                                               [ab]
# 17  [biegen, geben, sieben, gieren, rieben, lieben...
# 18
# 19  [feind, seid, fein, feil, feig, Neid, Leid, -eid]
# 20
# 21                  [weil, will, wild, wie, wir, Nil]
# 22                              [gilt, gibt, getippt]
# 23                           [der, er, per, her, wer]
# 24             [Kap, an, ad, au, am, ab, kp, aß, API]
# 25  [aale, alte, alle, adle, male, Aale, Wale, als...
# 26                               [fröhlich, freilich]
# 27                              [sind, seiend, säend]
# 28  [entzweigegangen, weggegangenen, weggegangen, ...
# 29                                        [natürlich]
# 30  [der, müder, oder, über, öder, Eder, Ader, erm...
# 31  [irr, er, gier, hier, vier, zier, Eier, Tier, ...
# 32
# 33   [harten, hadern, harren, harken, Garden, Barden]
# 34               [scheel, schnell, schnee-, schneeig]
# 35  [hasten, harten, hatten, halten, chaten, haute...
# 36               [arider, Marder, arger, armer, erde]
# 37                                   [Kugel, gurgeln]
# 38  [hat, haste, harte, hatte, halte, chate, haute...
# 39     [Geld, geld-, -geld, gelb, Held, Feld, gelind]

# %% [markdown]
# ### b) Token

# %%
# Create csv-file containing 'original'-column (misspelled) data to be analysed with hunspell
data_error_token.original.to_csv('original_hun_token.csv', header=False, index=False)

# The beforementioned csv-file is input to hunspell analysis with german dictionary;
# Output of analysis is put to a txt file
# Build a file 'hunspell.txt' with corrections for each word
# !cat original_hun_token.csv | hunspell -d de_DE > output_hun_token.txt
#!type original_hun.csv | hunspell -d de_DE > hunspell.txt



# Build a list (suggestions-column) of top correction suggestions from hunspell for each word, '' for correct, '?' for unrecognized
# Reading in all the lines
hs = []
with open('output_hun_token.txt') as f:
    next(f)
    for index, l in enumerate([l for l in [line.strip() for line in f] if l]):
        # Words recognized as correct
        # (* = dictionary stem (e. g. "man"), + = affixed forms of the following dictionary stem (e. g. "wollt" - wollen))
        # Append nothing to hs
        
        # TODO: Why minus flag?
        if re.match(r'\+|\*|-', l):
            hs.append('')
            
        # Words not recognized/rejected words (# = without suggestions)
        # Append '?' to hs
        elif re.match('#', l):
            hs.append('?')
            
        # Words not recognized/rejected words (& = with suggestions)
        # Append suggested words to hs
        else:
            hs.append(l.split(': ')[1].split(', '))

            
# Add hunspell's corrections as column to data
print(data_error_token.shape[0])
print(len(hs))

data_error_token['suggestions'] = hs

data_error_token.head(40)    # Print excerpt from DataFrame
# Out:
# 24601
# 24601
#          original       corrected              filename  freq_ori  freq_cor  \
# 0            belt           bellt  01-005-2-III-Eis.csv        91       138
# 1            kukt           kuckt  01-005-2-III-Eis.csv        73       152
# 2             dan            dann  01-005-2-III-Eis.csv       627       651
# 3        gekricht        gekriegt  01-005-2-III-Eis.csv         2        15
# 4           leken          lecken  01-005-2-III-Eis.csv        14        17
# 5            felt           fällt  01-005-2-III-Eis.csv        93       198
# 6           wolte          wollte  01-005-2-III-Eis.csv       173       201
# 7            lekt           leckt  01-005-2-III-Eis.csv        20        42
# 8             fom             vom  01-005-2-III-Eis.csv        13        16
# 9             dan            dann  01-005-2-III-Eis.csv       627       651
# 10            dan            dann  01-005-2-III-Eis.csv       627       651
# 11          leken          lecken  01-005-2-III-Eis.csv        14        17
# 12          gawen          kaufen  01-006-2-III-Eis.csv         1         6
# 13            din             ein  01-006-2-III-Eis.csv         2        26
# 14           Keld            Geld  01-006-2-III-Eis.csv         1         5
# 15            man            Mann  01-006-2-III-Eis.csv        79       132
# 16            man            Mann  01-006-2-III-Eis.csv        79       132
# 17           gien           gehen  01-006-2-III-Eis.csv         1        78
# 18        nahaise       nachhause  01-006-2-III-Eis.csv         1        10
# 19           esen           essen  01-006-2-III-Eis.csv        22        14
# 20           esen           essen  01-006-2-III-Eis.csv        22        14
# 21            aba            aber  01-006-2-III-Eis.csv        21        60
# 22         gieben           geben  01-006-2-III-Eis.csv         1         3
# 23          wollt          wollte  01-006-2-III-Eis.csv         2       201
# 24           feid           fällt  01-006-2-III-Eis.csv         1       198
# 25            gen           gehen  01-012-2-III-Eis.csv        31        78
# 26            wil            will  01-012-2-III-Eis.csv        95       157
# 27           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 28           felt           fällt  01-012-2-III-Eis.csv        93       198
# 29            ter             der  01-012-2-III-Eis.csv         1         9
# 30           felt           fällt  01-012-2-III-Eis.csv        93       198
# 31           lekt           leckt  01-012-2-III-Eis.csv        20        42
# 32           gipt            gibt  01-012-2-III-Eis.csv        18        42
# 33             ap              ab  01-012-2-III-Eis.csv        26        30
# 34            ale            alle  01-012-2-III-Eis.csv        34        39
# 35        frölich        fröhlich  01-012-2-III-Eis.csv        51        92
# 36          siend            sind  01-025-2-III-Eis.csv        16        66
# 37  weitagegangen  weitergegangen  01-025-2-III-Eis.csv         1         1
# 38       natürlig       natürlich  01-025-2-III-Eis.csv         1        19
# 39           üder            über  01-025-2-III-Eis.csv         8        35
#
#     freq_tup unchanged_original  \
# 0         91               belt
# 1         73               kukt
# 2        621                dan
# 3          2           gekricht
# 4         14              leken
# 5         90               felt
# 6        173              wolte
# 7         19               lekt
# 8         13                fom
# 9        621                dan
# 10       621                dan
# 11        14              leken
# 12         1              gawen
# 13         1                din
# 14         1               Keld
# 15        79                man
# 16        79                man
# 17         1               gien
# 18         1            nahaise
# 19        12               esen
# 20        12               esen
# 21        21                aba
# 22         1             gieben
# 23         2              wollt
# 24         1               feid
# 25        31                gen
# 26        95                wil
# 27        18               gipt
# 28        90               felt
# 29         1                ter
# 30        90               felt
# 31        19               lekt
# 32        18               gipt
# 33        26                 ap
# 34        33                ale
# 35        51            frölich
# 36        16              siend
# 37         1      weitagegangen
# 38         1           natürlig
# 39         8               üder
#
#                                           suggestions
# 0    [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                                        [kurt, bukt]
# 2   [da, an, dann, dran, dank, den, das, dar, ran,...
# 3      [gekracht, gekreischt, gerichtet, gerichtlich]
# 4   [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5   [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6                       [wollte, walte, wolle, holte]
# 7              [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                         [vom, Rom, Tom, Dom, fromm]
# 9   [da, an, dann, dran, dank, den, das, dar, ran,...
# 10  [da, an, dann, dran, dank, den, das, dar, ran,...
# 11  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 12                              [wagen, garen, gaben]
# 13  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 14                          [Geld, Held, Feld, Kelle]
# 15
# 16
# 17                          [gen, gier, Wien, gießen]
# 18                                        [nachweise]
# 19  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
# 20  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
# 21                                               [ab]
# 22  [biegen, geben, sieben, gieren, rieben, lieben...
# 23
# 24  [feind, seid, fein, feil, feig, Neid, Leid, -eid]
# 25
# 26                  [weil, will, wild, wie, wir, Nil]
# 27                              [gilt, gibt, getippt]
# 28  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 29                           [der, er, per, her, wer]
# 30  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 31             [lenkt, leckt, lest, legt, lebt, Sekt]
# 32                              [gilt, gibt, getippt]
# 33             [Kap, an, ad, au, am, ab, kp, aß, API]
# 34  [aale, alte, alle, adle, male, Aale, Wale, als...
# 35                               [fröhlich, freilich]
# 36                              [sind, seiend, säend]
# 37  [entzweigegangen, weggegangenen, weggegangen, ...
# 38                                        [natürlich]
# 39  [der, müder, oder, über, öder, Eder, Ader, erm...

# %%
# Write pickle
data_error_token.to_pickle('data_error_token_hunspell_suggestions.pkl')
data_error_types.to_pickle('data_error_types_hunspell_suggestions.pkl')

# %% [markdown]
# ## 3 - Evaluation
#
# - **Baseline**:<br>
# The baseline performance is created by checking whether the **target word** (= _**'corrected'**_) is in the **dictionary** (= _**'in_dict'**_) that is used by hunspell itself. It is checked, whether the word can basically be found.
#
#
# - **Furthermore, the following variables are created**:
#     - Whether the target word is among the suggested words by hunspell (= _**'in_sugg'**_).
#         - At which index it is among the suggested words by hunspell (= _**'sugg_index'**_).
#     - Whether the target word is ranked at index 0 by hunspell (= _**'idx0'**_).
#     - 'original_cs', 'corrected_cs', 'suggestions_cs': All columns (3) in case sensitive (distinction upper- and lower case)

# %%
# Read pickle
data_error_token = pd.read_pickle('data_error_token_hunspell_suggestions.pkl')
data_error_types = pd.read_pickle('data_error_types_hunspell_suggestions.pkl')

# %%
display(data_error_token.head(20))
display(data_error_types.head(20))
# no suggestion: empty cell
# Out:
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 10       dan       dann  01-005-2-III-Eis.csv       627       651       621
# 11     leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 12     gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 13       din        ein  01-006-2-III-Eis.csv         2        26         1
# 14      Keld       Geld  01-006-2-III-Eis.csv         1         5         1
# 15       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 16       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 17      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 18   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 19      esen      essen  01-006-2-III-Eis.csv        22        14        12
#
#    unchanged_original                                        suggestions
# 0                belt   [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                 fom                        [vom, Rom, Tom, Dom, fromm]
# 9                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 10                dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 11              leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 12              gawen                              [wagen, garen, gaben]
# 13                din  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 14               Keld                          [Geld, Held, Feld, Kelle]
# 15                man
# 16                man
# 17               gien                          [gen, gier, Wien, gießen]
# 18            nahaise                                        [nachweise]
# 19               esen  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9      gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 10       din        ein  01-006-2-III-Eis.csv         2        26         1
# 11      Keld       Geld  01-006-2-III-Eis.csv         1         5         1
# 12       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 13      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 14   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 15      esen      essen  01-006-2-III-Eis.csv        22        14        12
# 16       aba       aber  01-006-2-III-Eis.csv        21        60        21
# 17    gieben      geben  01-006-2-III-Eis.csv         1         3         1
# 18     wollt     wollte  01-006-2-III-Eis.csv         2       201         2
# 19      feid      fällt  01-006-2-III-Eis.csv         1       198         1
#
#    unchanged_original                                        suggestions
# 0                belt   [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                 fom                        [vom, Rom, Tom, Dom, fromm]
# 9               gawen                              [wagen, garen, gaben]
# 10                din  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 11               Keld                          [Geld, Held, Feld, Kelle]
# 12                man
# 13               gien                          [gen, gier, Wien, gießen]
# 14            nahaise                                        [nachweise]
# 15               esen  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
# 16                aba                                               [ab]
# 17             gieben  [biegen, geben, sieben, gieren, rieben, lieben...
# 18              wollt
# 19               feid  [feind, seid, fein, feil, feig, Neid, Leid, -eid]

# %%
# Check if empty suggestion cell is nan
#data_error_token.info()
#data_error_token[data_error_token.suggestions.isna()]
# EMPTY CELL CONTAINS EMPTY STRING, SEE ABOVE

# %%
data_error_token.suggestions.iloc[0]
data_error_token.corrected.iloc[0]
data_error_token.suggestions.iloc[2].index(data_error_token.corrected.iloc[2]) # (bellt on index 1, dann on index 2) TRUE

#data_ready.corrected.iloc[2]
#.index(data_ready.corrected.iloc[2]) # bellt 1
#(data_ready.corrected.iloc[0])
#data_ready.corrected.iloc[0]
# Out:
# 2

# %%
data_error_types_lc = litkey_2.evaluate(data_error_types)
data_error_token_lc = litkey_2.evaluate(data_error_token)

data_error_types_cs = litkey_2.evaluate(data_error_types, lower_case=False)
data_error_token_cs = litkey_2.evaluate(data_error_token, lower_case=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9484.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=24601.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9484.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=24601.0), HTML(value='')))

# %%
display(data_error_types_lc.head(20))
display(data_error_types_cs.head(20))
# Out:
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9      gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 10       din        ein  01-006-2-III-Eis.csv         2        26         1
# 11      keld       geld  01-006-2-III-Eis.csv         1         5         1
# 12       man       mann  01-006-2-III-Eis.csv        79       132        79
# 13      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 14   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 15      esen      essen  01-006-2-III-Eis.csv        22        14        12
# 16       aba       aber  01-006-2-III-Eis.csv        21        60        21
# 17    gieben      geben  01-006-2-III-Eis.csv         1         3         1
# 18     wollt     wollte  01-006-2-III-Eis.csv         2       201         2
# 19      feid      fällt  01-006-2-III-Eis.csv         1       198         1
#
#    unchanged_original                                        suggestions  \
# 0                belt   [lebt, bellt, bebt, welt, zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, sekt]
# 8                 fom                        [vom, rom, tom, dom, fromm]
# 9               gawen                              [wagen, garen, gaben]
# 10                din  [din, in, dein, drin, die, den, ein, dir, hin,...
# 11               Keld                          [geld, held, feld, kelle]
# 12                man
# 13               gien                          [gen, gier, wien, gießen]
# 14            nahaise                                        [nachweise]
# 15               esen  [essen, lesen, lesen, besen, wesen, eben, äsen...
# 16                aba                                               [ab]
# 17             gieben  [biegen, geben, sieben, gieren, rieben, lieben...
# 18              wollt
# 19               feid  [feind, seid, fein, feil, feig, neid, leid, -eid]
#
#    in_sugg  sugg_idx   idx0
# 0     True       1.0  False
# 1    False       NaN  False
# 2     True       2.0  False
# 3    False       NaN  False
# 4     True       1.0  False
# 5    False       NaN  False
# 6     True       0.0   True
# 7     True       1.0  False
# 8     True       0.0   True
# 9    False       NaN  False
# 10    True       6.0  False
# 11    True       0.0   True
# 12   False       NaN  False
# 13   False       NaN  False
# 14   False       NaN  False
# 15    True       0.0   True
# 16   False       NaN  False
# 17    True       1.0  False
# 18   False       NaN  False
# 19   False       NaN  False
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9      gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 10       din        ein  01-006-2-III-Eis.csv         2        26         1
# 11      Keld       Geld  01-006-2-III-Eis.csv         1         5         1
# 12       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 13      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 14   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 15      esen      essen  01-006-2-III-Eis.csv        22        14        12
# 16       aba       aber  01-006-2-III-Eis.csv        21        60        21
# 17    gieben      geben  01-006-2-III-Eis.csv         1         3         1
# 18     wollt     wollte  01-006-2-III-Eis.csv         2       201         2
# 19      feid      fällt  01-006-2-III-Eis.csv         1       198         1
#
#    unchanged_original                                        suggestions  \
# 0                belt   [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                 fom                        [vom, Rom, Tom, Dom, fromm]
# 9               gawen                              [wagen, garen, gaben]
# 10                din  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 11               Keld                          [Geld, Held, Feld, Kelle]
# 12                man
# 13               gien                          [gen, gier, Wien, gießen]
# 14            nahaise                                        [nachweise]
# 15               esen  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
# 16                aba                                               [ab]
# 17             gieben  [biegen, geben, sieben, gieren, rieben, lieben...
# 18              wollt
# 19               feid  [feind, seid, fein, feil, feig, Neid, Leid, -eid]
#
#    in_sugg  sugg_idx   idx0
# 0     True       1.0  False
# 1    False       NaN  False
# 2     True       2.0  False
# 3    False       NaN  False
# 4     True       1.0  False
# 5    False       NaN  False
# 6     True       0.0   True
# 7     True       1.0  False
# 8     True       0.0   True
# 9    False       NaN  False
# 10    True       6.0  False
# 11    True       0.0   True
# 12   False       NaN  False
# 13   False       NaN  False
# 14   False       NaN  False
# 15    True       0.0   True
# 16   False       NaN  False
# 17    True       1.0  False
# 18   False       NaN  False
# 19   False       NaN  False

# %%
display(data_error_token_lc.head(20))
display(data_error_token_cs.head(20))
# Out:
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 10       dan       dann  01-005-2-III-Eis.csv       627       651       621
# 11     leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 12     gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 13       din        ein  01-006-2-III-Eis.csv         2        26         1
# 14      keld       geld  01-006-2-III-Eis.csv         1         5         1
# 15       man       mann  01-006-2-III-Eis.csv        79       132        79
# 16       man       mann  01-006-2-III-Eis.csv        79       132        79
# 17      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 18   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 19      esen      essen  01-006-2-III-Eis.csv        22        14        12
#
#    unchanged_original                                        suggestions  \
# 0                belt   [lebt, bellt, bebt, welt, zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, sekt]
# 8                 fom                        [vom, rom, tom, dom, fromm]
# 9                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 10                dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 11              leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 12              gawen                              [wagen, garen, gaben]
# 13                din  [din, in, dein, drin, die, den, ein, dir, hin,...
# 14               Keld                          [geld, held, feld, kelle]
# 15                man
# 16                man
# 17               gien                          [gen, gier, wien, gießen]
# 18            nahaise                                        [nachweise]
# 19               esen  [essen, lesen, lesen, besen, wesen, eben, äsen...
#
#    in_sugg  sugg_idx   idx0
# 0     True       1.0  False
# 1    False       NaN  False
# 2     True       2.0  False
# 3    False       NaN  False
# 4     True       1.0  False
# 5    False       NaN  False
# 6     True       0.0   True
# 7     True       1.0  False
# 8     True       0.0   True
# 9     True       2.0  False
# 10    True       2.0  False
# 11    True       1.0  False
# 12   False       NaN  False
# 13    True       6.0  False
# 14    True       0.0   True
# 15   False       NaN  False
# 16   False       NaN  False
# 17   False       NaN  False
# 18   False       NaN  False
# 19    True       0.0   True
#     original  corrected              filename  freq_ori  freq_cor  freq_tup  \
# 0       belt      bellt  01-005-2-III-Eis.csv        91       138        91
# 1       kukt      kuckt  01-005-2-III-Eis.csv        73       152        73
# 2        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 3   gekricht   gekriegt  01-005-2-III-Eis.csv         2        15         2
# 4      leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 5       felt      fällt  01-005-2-III-Eis.csv        93       198        90
# 6      wolte     wollte  01-005-2-III-Eis.csv       173       201       173
# 7       lekt      leckt  01-005-2-III-Eis.csv        20        42        19
# 8        fom        vom  01-005-2-III-Eis.csv        13        16        13
# 9        dan       dann  01-005-2-III-Eis.csv       627       651       621
# 10       dan       dann  01-005-2-III-Eis.csv       627       651       621
# 11     leken     lecken  01-005-2-III-Eis.csv        14        17        14
# 12     gawen     kaufen  01-006-2-III-Eis.csv         1         6         1
# 13       din        ein  01-006-2-III-Eis.csv         2        26         1
# 14      Keld       Geld  01-006-2-III-Eis.csv         1         5         1
# 15       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 16       man       Mann  01-006-2-III-Eis.csv        79       132        79
# 17      gien      gehen  01-006-2-III-Eis.csv         1        78         1
# 18   nahaise  nachhause  01-006-2-III-Eis.csv         1        10         1
# 19      esen      essen  01-006-2-III-Eis.csv        22        14        12
#
#    unchanged_original                                        suggestions  \
# 0                belt   [lebt, bellt, bebt, Welt, Zelt, hebelt, bettelt]
# 1                kukt                                       [kurt, bukt]
# 2                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 3            gekricht     [gekracht, gekreischt, gerichtet, gerichtlich]
# 4               leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 5                felt  [fehlt, feilt, fielt, elft, fest, fett, fegt, ...
# 6               wolte                      [wollte, walte, wolle, holte]
# 7                lekt             [lenkt, leckt, lest, legt, lebt, Sekt]
# 8                 fom                        [vom, Rom, Tom, Dom, fromm]
# 9                 dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 10                dan  [da, an, dann, dran, dank, den, das, dar, ran,...
# 11              leken  [lenken, lecken, ekeln, lenke, lesen, legen, l...
# 12              gawen                              [wagen, garen, gaben]
# 13                din  [DIN, in, dein, drin, die, den, ein, dir, hin,...
# 14               Keld                          [Geld, Held, Feld, Kelle]
# 15                man
# 16                man
# 17               gien                          [gen, gier, Wien, gießen]
# 18            nahaise                                        [nachweise]
# 19               esen  [essen, lesen, Lesen, Besen, Wesen, eben, äsen...
#
#    in_sugg  sugg_idx   idx0
# 0     True       1.0  False
# 1    False       NaN  False
# 2     True       2.0  False
# 3    False       NaN  False
# 4     True       1.0  False
# 5    False       NaN  False
# 6     True       0.0   True
# 7     True       1.0  False
# 8     True       0.0   True
# 9     True       2.0  False
# 10    True       2.0  False
# 11    True       1.0  False
# 12   False       NaN  False
# 13    True       6.0  False
# 14    True       0.0   True
# 15   False       NaN  False
# 16   False       NaN  False
# 17   False       NaN  False
# 18   False       NaN  False
# 19    True       0.0   True

# %%
# Serialize dataframe, so that analysis does not have to be run every single time
# Dataframe can then be deserialized in another notebook
data_error_token_lc.to_pickle('data_error_token_hunspell_evaluation_lc.pkl')
data_error_types_lc.to_pickle('data_error_types_hunspell_evaluation_lc.pkl')

data_error_token_cs.to_pickle('data_error_token_hunspell_evaluation_cs.pkl')
data_error_types_cs.to_pickle('data_error_types_hunspell_evaluation_cs.pkl')

# %%
# Reload pickle
# Load df from pickle

#data_error_token = pd.read_pickle('data_error_token_hunspell_evaluation.pkl')
#data_error_types = pd.read_pickle('data_error_types_hunspell_evaluation.pkl')
