# %% [markdown]
# - Run through on server with script language_tool_texts.py (**_before_**)
# - <span style='background:yellow'> **Important note: Since errors have been analyzed within a full text, these are only analysed on token level. No types are to be reconstructed!** </span>
#
# 1. Read in results from server (**_preparation_**)
# 2. Extract misspellings (originals) + replacements (suggestions)
# 3. Get reference df to merge with
#     - Load original texts
#         - Preprocess as before
#         - Get offsets
# 4. Merge back to original df
#     - data_error_types
#     - data_error_token
# 5. Drop words that are not examined in analysis
#     - Remove words/characters that are not desired in analysis
#     - Drop obsolete columns
#
#
# - EVALUATION
#     - TOKEN ONLY
#     - Case in- and -sensitive

# %%
import pandas as pd
import pickle
import glob
import csv
import os

import sys
sys.path.insert(0, '../../Lisa')
import litkey_2
import helpers_litkey_2 as helpers

import helpers_lt

# %%
# Do not truncate rows of DataFrame
pd.set_option('display.max_rows', None)
# Do not truncate column width
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 1 - Read in results from server

# %%
x = pd.read_pickle('./Output_LT/matches_texts.pkl') # list

# %%
# Multidimensional list
# Access attribute of element/match x[0][0].replacements

print(len(x)) # 1922 texts
print(len(x[1000])) # 20 matches in text 1000
print(type(x[1000])) # list
print(type(x[1000][19])) # language_tool_python.match.Match
# Out:
# 1922
# 22
# <class 'list'>
# <class 'language_tool_python.match.Match'>

# %%
x[1000][19].errorLength
# Out:
# 4

# %%
#x[0:1]

# %% [markdown]
# ## 2 - Extract misspellings (originals) + replacements (suggestions)

# %%
# Get whole texts
whole_texts = []

for csv_file in sorted(glob.glob(r'./Input_texts_csv/'+'*.csv')):
    with open(csv_file, 'r', encoding='utf-8') as f:
        # not readlines
        # read file as a whole, i. e. all texts
       
        text = f.read()
        #csv.reader(f, delimiter)
        text_n = text.replace('\n', ' ')
        #text_prep = text_n.replace(' .', '.')

        whole_texts.append(text_n)

# %%
#whole_texts

# %%
# each text as list element
type(whole_texts) # list
type(whole_texts[0]) # str
# Out:
# str

# %%
# Extract mistakes and corrections
start_positions = []
end_positions = []
num_texts = []
#offsets = []
#error_lengths = []

my_mistakes = []
my_corrections = []

rule_id = []

text_count = 0

for text in x:
    
    for match in text:
    
        #print(type(i))
        #print(i)
        start_positions.append(match.offset)
        end_positions.append(match.errorLength+match.offset)
        num_texts.append(text_count)
        
        my_mistakes.append(whole_texts[text_count][match.offset:match.errorLength+match.offset])
        my_corrections.append(match.replacements)
        
        rule_id.append(match.ruleId)
        
    text_count+=1

# %%
error_list_full = list(zip(my_mistakes,my_corrections,rule_id,num_texts,start_positions,end_positions))

# %%
# Convert to df
df_server = pd.DataFrame(data=error_list_full, columns=['original','suggestions','rule_id','num_texts','start_position','end_position'])

# %%
df_server.head(10)
#df_server.tail(20)
# Out:
#     original  \
# 0       Dodo
# 1       Dodo
# 2       belt
# 3       kukt
# 4       Dodo
# 5        dan
# 6  Ihren Eis
# 7   gekricht
# 8      leken
# 9       felt
#
#                                                                                                                                                                                     suggestions  \
# 0                                                                       [Foto, Tot, Voodoo, Dato, Bodo, Dojo, Tote, Toto, Tod, Töte, Dorf, Dito, Otto, Bot, Gott, Dort, Motor, Doch, Tode, Rot]
# 1                                                                       [Foto, Tot, Voodoo, Dato, Bodo, Dojo, Tote, Toto, Tod, Töte, Dorf, Dito, Otto, Bot, Gott, Dort, Motor, Doch, Tode, Rot]
# 2                                                                   [Belt, Welt, bald, hält, Geld, Feld, Held, Zelt, bebt, bellt, perlt, pell, best, meld, peilt, pellt, pult, zelt, bei, seit]
# 3                                                       [rückt, zückt, bückt, guckt, kickt, kackt, gut, rückte, deckt, fügt, Lücke, lockt, weckt, packt, Mücke, kund, kürt, lügt, hackt, hockt]
# 4                                                                       [Foto, Tot, Voodoo, Dato, Bodo, Dojo, Tote, Toto, Tod, Töte, Dorf, Dito, Otto, Bot, Gott, Dort, Motor, Doch, Tode, Rot]
# 5                                                                                       [dann, Dan, den, an, das, man, da, dar, van, San, tun, Jan, dank, tat, dran, ran, tank, Fan, Idan, Pan]
# 6                                                                                                                                                  [Ihr Eis, Ihrem Eis, Ihren Eiern, Ihres Eis]
# 7  [gebricht, gegeigt, gekickt, gekracht, gebracht, geprägt, gezeigt, Gericht, Bericht, gefragt, gerecht, gekocht, geneigt, gereicht, Rücksicht, gerückt, geklagt, geeicht, gegrillt, geknickt]
# 8                                      [legen, locken, lägen, Säcken, lecken, gegen, wegen, leben, lagen, lesen, Becken, decken, dicken, legten, lenken, locker, regen, rücken, Lücken, Nacken]
# 9                                                                      [Welt, fest, fällt, hält, Geld, fehlt, Feld, Held, fett, Zelt, fegt, Belt, feilt, feit, fielt, meld, pfählt, zelt, seit]
#
#                rule_id  num_texts  start_position  end_position
# 0  GERMAN_SPELLER_RULE          0              17            21
# 1  GERMAN_SPELLER_RULE          0              41            45
# 2  GERMAN_SPELLER_RULE          0              46            50
# 3  GERMAN_SPELLER_RULE          0              80            84
# 4  GERMAN_SPELLER_RULE          0              85            89
# 5  GERMAN_SPELLER_RULE          0              95            98
# 6         DE_AGREEMENT          0             109           118
# 7  GERMAN_SPELLER_RULE          0             119           127
# 8  GERMAN_SPELLER_RULE          0             136           141
# 9  GERMAN_SPELLER_RULE          0             164           168

# %%
df_server.tail(10)
# Out:
#       original  \
# 42550    einen
# 42551  zur Tor
# 42552   umarte
# 42553      Lar
# 42554    nieht
# 42555     Dodo
# 42556      ass
# 42557   mutzte
# 42558    momen
# 42559  Lutscha
#
#                                                                                                                                                                      suggestions  \
# 42550                                                                                                                                                                    [einem]
# 42551                                                                                                                                                                  [dem Tor]
# 42552               [um arte, smarte, umarmte, umarme, Karte, harte, malte, uralte, arte, klärte, marode, sparte, umbaute, zarte, Quarte, matte, smart, starte, umarmen, umarmt]
# 42553                                                                 [War, Dar, Gar, Lag, Bar, Zar, Klar, Bär, Lars, Las, Lahr, Lara, Lärm, Rar, Wär, Lear, Lau, Lax, Aar, Lab]
# 42554                                  [nicht, sieht, zieht, niet, lieht, niest, liegt, geht, steht, dient, hielt, nichts, nie, nimmt, siehe, Licht, Sicht, dicht, dreht, liebt]
# 42555                                                    [Foto, Tot, Voodoo, Dato, Bodo, Dojo, Tote, Toto, Tod, Töte, Dorf, Dito, Otto, Bot, Gott, Dort, Motor, Doch, Tode, Rot]
# 42556                                                               [Ass, aß, als, aus, dass, ans, saß, Hass, Fass, nass, bass, lass, pass, Bass, Pass, aßt, iss, äse, äst, des]
# 42557           [musste, nutzte, müsste, nützte, mutete, bützte, motzte, münzte, putzte, setzte, letzte, mussten, müsse, nutzt, Hütte, Künste, meiste, müssten, nutzten, wusste]
# 42558                             [mögen, Domen, mimen, zoomen, Nomen, boomen, Namen, kamen, hohen, oben, Polen, Roman, hören, roten, zogen, Boden, lösen, töten, Böhmen, Löwen]
# 42559  [Lutsch, Luigi, Lutsche, Lunge, Lutscht, Putsch, Kutsche, Rutscht, Ludger, Lusaka, Putsche, Luchs, Rutsche, Luchse, Rutsch, Latsche, Blutschau, Datscha, Dougga, Hodscha]
#
#                    rule_id  num_texts  start_position  end_position
# 42550              DEN_DEM       1921             770           775
# 42551         DE_AGREEMENT       1921             816           823
# 42552  GERMAN_SPELLER_RULE       1921             828           834
# 42553  GERMAN_SPELLER_RULE       1921             835           838
# 42554  GERMAN_SPELLER_RULE       1921             886           891
# 42555  GERMAN_SPELLER_RULE       1921             894           898
# 42556  GERMAN_SPELLER_RULE       1921             912           915
# 42557  GERMAN_SPELLER_RULE       1921             923           929
# 42558  GERMAN_SPELLER_RULE       1921             934           939
# 42559  GERMAN_SPELLER_RULE       1921             962           969

# %%
df_server.shape[0] 
# Before troubleshooting 42038 token
# After troubleshooting 42560 token
# Out:
# 42560

# %% [markdown]
# ## 3 - Get reference df to merge with
# - Load original texts
# - Preprocess (... as before)
# - Get offsets

# %%
# Get original texts, i. e. data_raw_token
# In data_raw_token, NA-cases and headline markers are already removed
#original_texts = litkey_2.load_raw(litkey_data_path = "../../litkey-data/")

# %%
def combineCsvsToDataframe_x(data_path):
    df=[] # type: list
    
    text_count = 0
    
    for csv_file in sorted(glob.glob(data_path+"*.csv")):
        frame = pd.read_csv(filepath_or_buffer=csv_file, sep='\t', quoting=csv.QUOTE_NONE, names=['original', 'corrected']) # Get columns (o & c)
        frame['filename'] = os.path.basename(csv_file) # Get column filename
        frame['num_texts'] = text_count
        df.append(frame)
        
        text_count+=1
        
    #display(type(frame)) : DataFrame
    #display(type(df)) : List
    df = pd.concat(df)
    return df

# %%
def load_raw_x(data):

    # REMOVE NA-CASES, i. e. line-ends (^) (no other relevant NA-cases)
    data.dropna(subset=['original','corrected'], inplace=True)
    
    # REMOVE HEADLINE MARKERS, i. e. \h
    data = data[~data.original.str.contains(r'\\h')]
    
    # Reset index
    data.reset_index(drop=True, inplace=True)
    
    return data

# %%
original_texts_prep = combineCsvsToDataframe_x("../../litkey-data/")
original_texts = load_raw_x(original_texts_prep)

# %%
# Preprocessing like in language_tool_prep.ipynb
# Remove "|" and "_" characters, i. e. original is one/two-word whereas target is two/one-word
original_texts['original']=original_texts['original'].str.replace(r'[\|\_]', '', regex=True)
original_texts['corrected']=original_texts['corrected'].str.replace(r'[\|\_]', '', regex=True)
    
# Remove intended line-break characters '^', '-^', '^-'
pattern = r'(\-\^)|(\^\-)|(\^)'
original_texts['original'] = original_texts['original'].str.replace(pattern, '', regex=True)
    
# Remove words containing illegible character(s), i. e. containing '*' (original)
original_texts = original_texts[~original_texts.original.str.contains(r'\*')]
    
# Remove non-words ('?' target not identifiable or no standardized spelling | '~' target non existing word form)
original_texts = original_texts[~original_texts.corrected.str.contains(r'\?|\~')]
# Out:
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_81567/983848328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_texts['original']=original_texts['original'].str.replace(r'[\|\_]', '', regex=True)
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_81567/983848328.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_texts['corrected']=original_texts['corrected'].str.replace(r'[\|\_]', '', regex=True)
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_81567/983848328.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_texts['original'] = original_texts['original'].str.replace(pattern, '', regex=True)

# %%
original_texts.reset_index(drop=True, inplace=True)
#original_texts.tail(100)

# %%
# Get list of filenames
filename_list = list(original_texts.filename.unique())

# %%
# Initialize empty columns
original_texts['length'] = ''
original_texts['start_position'] = ''
original_texts['end_position'] = ''
original_texts['ct'] = ''

# %%
original_texts.head(2)
# Out:
#   original corrected              filename  num_texts length start_position  \
# 0      Lea       Lea  01-005-2-III-Eis.csv          0
# 1      und       und  01-005-2-III-Eis.csv          0
#
#   end_position ct
# 0
# 1

# %%
# GET START POSITION
def get_starts(df):
    for i in range(len(df)):
        if df.loc[i, 'ct'] == 0:
            df.loc[i, 'start_position'] = 0
        #elif df.loc[i, 'original'] == '.':
        #    df.loc[i, 'start_position'] = df.loc[i-1, 'start_position'] + df.loc[i-1, 'length']
        else:
            df.loc[i, 'start_position'] = df.loc[i-1, 'start_position'] + df.loc[i-1, 'length'] + 1
            # if punkt, dann nicht +1
    return df

# %%
# GET END POSITION
def get_ends(df):
    for i in range(len(df)):
        df.loc[i, 'end_position'] =  df.loc[i, 'start_position'] + df.loc[i, 'length']
    return df

# %%
ref_list = []

for file in filename_list:
    # Get part of the dataframe that matches filename
    
    df = original_texts.loc[original_texts.filename == file]
    df.reset_index(inplace=True)
    df['ct'] = df.index
    
    df['length'] = df.apply(lambda x: len(x.original), axis=1)
   
    # ASSIGN RETURN VALUE LOL
    df = get_starts(df)
    df = get_ends(df)
    
    ref_list.append(df)

# RETURN VALUES ARE NOW IN DF NOT IN ORIGINAL_TEXTS
# Out:
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_88866/2396279747.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ct'] = df.index
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_88866/2396279747.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['length'] = df.apply(lambda x: len(x.original), axis=1)
# /Users/lisaprepens/anaconda3/envs/bodu-spell_Env/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Convert list to dataframe
ref_list = pd.concat(ref_list)

# %%
ref_list.shape[0] # 210771 token
# Out:
# 210771

# %%
ref_list.tail(10)
# Out:
#       index   original  corrected             filename  num_texts  length  \
# 196  212493         zu         zu  10-693-4-IV-Weg.csv       1921       2
# 197  212494   schenken   schenken  10-693-4-IV-Weg.csv       1921       8
# 198  212495          .          .  10-693-4-IV-Weg.csv       1921       1
# 199  212496       P.S.       P.S.  10-693-4-IV-Weg.csv       1921       4
# 200  212497       Lars       Lars  10-693-4-IV-Weg.csv       1921       4
# 201  212498        ist        ist  10-693-4-IV-Weg.csv       1921       3
# 202  212499         in         in  10-693-4-IV-Weg.csv       1921       2
# 203  212500        Lea        Lea  10-693-4-IV-Weg.csv       1921       3
# 204  212501  verknallt  verknallt  10-693-4-IV-Weg.csv       1921       9
# 205  212502          .          .  10-693-4-IV-Weg.csv       1921       1
#
#     start_position end_position   ct
# 196            970          972  196
# 197            973          981  197
# 198            982          983  198
# 199            984          988  199
# 200            989          993  200
# 201            994          997  201
# 202            998         1000  202
# 203           1001         1004  203
# 204           1005         1014  204
# 205           1015         1016  205

# %%
# Zwischenstand
#ref_list.to_pickle('data_raw_token_whole_texts_offsets.pkl')
#ref_list.to_pickle('data_raw_token_whole_texts_offsets_OTHERINDEX_20211208.pkl')

# %%
#ref_list = pd.read_pickle('./pickles/data_raw_token_whole_texts_offsets.pkl')
ref_list = pd.read_pickle('./pickles/data_raw_token_whole_texts_offsets_OTHERINDEX_20211208.pkl')

# %%
#ref_list.head(10)
ref_list.tail(10)
ref_list.shape[0]
# Out:
# 210771

# %% [markdown]
# ## 4 - Merge back to original df
# - data_error_token

# %%
# MERGE (original_texts, df_server)
suggs = ref_list.merge(df_server, how='left', on=['original', 'num_texts', 'start_position', 'end_position'])

# %%
# CHECK FOR DUPLICATES; Mark all duplicates as True
# Server results
df_server[df_server.duplicated(subset=['original', 'num_texts', 'start_position', 'end_position'], keep=False)] # 10.390 / 42.038
# Out:
# Empty DataFrame
# Columns: [original, suggestions, rule_id, num_texts, start_position, end_position]
# Index: []

# %%
# Reference dataframe
ref_list[ref_list.duplicated(subset=['original', 'num_texts', 'start_position', 'end_position'], keep=False)] # 116.691 / 210.771
# Out:
# Empty DataFrame
# Columns: [index, original, corrected, filename, num_texts, length, start_position, end_position, ct]
# Index: []

# %%
suggs.shape[0] # equals ref_list
# Out:
# 210771

# %%
suggs.tail(10) # 210770 with resetted index
# Out:
#          index   original  corrected             filename  num_texts  length  \
# 210761  210761         zu         zu  10-693-4-IV-Weg.csv       1921       2
# 210762  210762   schenken   schenken  10-693-4-IV-Weg.csv       1921       8
# 210763  210763          .          .  10-693-4-IV-Weg.csv       1921       1
# 210764  210764       P.S.       P.S.  10-693-4-IV-Weg.csv       1921       4
# 210765  210765       Lars       Lars  10-693-4-IV-Weg.csv       1921       4
# 210766  210766        ist        ist  10-693-4-IV-Weg.csv       1921       3
# 210767  210767         in         in  10-693-4-IV-Weg.csv       1921       2
# 210768  210768        Lea        Lea  10-693-4-IV-Weg.csv       1921       3
# 210769  210769  verknallt  verknallt  10-693-4-IV-Weg.csv       1921       9
# 210770  210770          .          .  10-693-4-IV-Weg.csv       1921       1
#
#        start_position end_position   ct suggestions rule_id
# 210761            970          972  196         NaN     NaN
# 210762            973          981  197         NaN     NaN
# 210763            982          983  198         NaN     NaN
# 210764            984          988  199         NaN     NaN
# 210765            989          993  200         NaN     NaN
# 210766            994          997  201         NaN     NaN
# 210767            998         1000  202         NaN     NaN
# 210768           1001         1004  203         NaN     NaN
# 210769           1005         1014  204         NaN     NaN
# 210770           1015         1016  205         NaN     NaN

# %%
suggs.tail(10) # 210770 with non-resetted index
# Out:
#          index   original  corrected             filename  num_texts  length  \
# 210761  210761         zu         zu  10-693-4-IV-Weg.csv       1921       2
# 210762  210762   schenken   schenken  10-693-4-IV-Weg.csv       1921       8
# 210763  210763          .          .  10-693-4-IV-Weg.csv       1921       1
# 210764  210764       P.S.       P.S.  10-693-4-IV-Weg.csv       1921       4
# 210765  210765       Lars       Lars  10-693-4-IV-Weg.csv       1921       4
# 210766  210766        ist        ist  10-693-4-IV-Weg.csv       1921       3
# 210767  210767         in         in  10-693-4-IV-Weg.csv       1921       2
# 210768  210768        Lea        Lea  10-693-4-IV-Weg.csv       1921       3
# 210769  210769  verknallt  verknallt  10-693-4-IV-Weg.csv       1921       9
# 210770  210770          .          .  10-693-4-IV-Weg.csv       1921       1
#
#        start_position end_position   ct suggestions rule_id
# 210761            970          972  196         NaN     NaN
# 210762            973          981  197         NaN     NaN
# 210763            982          983  198         NaN     NaN
# 210764            984          988  199         NaN     NaN
# 210765            989          993  200         NaN     NaN
# 210766            994          997  201         NaN     NaN
# 210767            998         1000  202         NaN     NaN
# 210768           1001         1004  203         NaN     NaN
# 210769           1005         1014  204         NaN     NaN
# 210770           1015         1016  205         NaN     NaN

# %% [markdown]
# ## 5 - Drop words that are not examined in analysis
# - Remove words/characters that are not desired in analysis (**_in alignment with language_tool_prep Notebook_**)
# - Drop obsolete columns
# - Get other information to complete df
#
# - Get Types

# %%
# Get clean data
suggs_clean_token = helpers_lt.removeCharactersWords_x(suggs)

# %%
suggs_clean_token.head(2)
suggs_clean_token.tail(2)
# Out:
#          index   original  corrected             filename  num_texts  length  \
# 210767  210767         in         in  10-693-4-IV-Weg.csv       1921       2
# 210769  210769  verknallt  verknallt  10-693-4-IV-Weg.csv       1921       9
#
#        start_position end_position   ct suggestions rule_id
# 210767            998         1000  202         NaN     NaN
# 210769           1005         1014  204         NaN     NaN

# %%
# Get error data
suggs_error_token = helpers.removeCorrectWords(suggs_clean_token)

# %%
suggs_error_token.head(2)
suggs_error_token.tail(2)
# Out:
#          index original corrected             filename  num_texts  length  \
# 210754  210754    momen    Moment  10-693-4-IV-Weg.csv       1921       5
# 210760  210760  Lutscha  Lutscher  10-693-4-IV-Weg.csv       1921       7
#
#        start_position end_position   ct  \
# 210754            934          939  189
# 210760            962          969  195
#
#                                                                                                                                                                       suggestions  \
# 210754                             [mögen, Domen, mimen, zoomen, Nomen, boomen, Namen, kamen, hohen, oben, Polen, Roman, hören, roten, zogen, Boden, lösen, töten, Böhmen, Löwen]
# 210760  [Lutsch, Luigi, Lutsche, Lunge, Lutscht, Putsch, Kutsche, Rutscht, Ludger, Lusaka, Putsche, Luchs, Rutsche, Luchse, Rutsch, Latsche, Blutschau, Datscha, Dougga, Hodscha]
#
#                     rule_id
# 210754  GERMAN_SPELLER_RULE
# 210760  GERMAN_SPELLER_RULE

# %%
# Drop obsolete columns
#suggs_error_token_x = suggs_error_token.drop(columns=['index', 'num_texts', 'length', 'start_position', 'end_position', 'ct'])
suggs_error_token_x = suggs_error_token

# %%
suggs_error_token_x.head(2)
#suggs_error_token_x.shape[0]
# Out:
#     index original corrected              filename  num_texts  length  \
# 10     10     belt     bellt  01-005-2-III-Eis.csv          0       4
# 17     17     kukt     kuckt  01-005-2-III-Eis.csv          0       4
#
#    start_position end_position  ct  \
# 10             46           50  10
# 17             80           84  17
#
#                                                                                                                                 suggestions  \
# 10              [Belt, Welt, bald, hält, Geld, Feld, Held, Zelt, bebt, bellt, perlt, pell, best, meld, peilt, pellt, pult, zelt, bei, seit]
# 17  [rückt, zückt, bückt, guckt, kickt, kackt, gut, rückte, deckt, fügt, Lücke, lockt, weckt, packt, Mücke, kund, kürt, lügt, hackt, hockt]
#
#                 rule_id
# 10  GERMAN_SPELLER_RULE
# 17  GERMAN_SPELLER_RULE

# %%
# Get other information to complete data (token tupel counts)
def get_tupel_counts(data):
    # Tupel frequency is returned as a multi-indexed Series, therefore merging is different
    data['freq_ori'] = data.groupby('original').size()[data.original].values
    data['freq_cor'] = data.groupby('corrected').size()[data.corrected].values
    
    freq_tupel = data.groupby(['original','corrected']).size()
    data = data.merge(freq_tupel.to_frame(), how='left', left_on=['original', 'corrected'], right_on=['original', 'corrected'])
    data.rename({0: 'freq_tup'}, axis='columns', inplace = True)
    
    return data

# %%
suggs_error_token_x = get_tupel_counts(suggs_error_token_x)
# Out:
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_81567/3285557738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['freq_ori'] = data.groupby('original').size()[data.original].values
# /var/folders/fm/3v9lhcw93xj0g_xd62n6f9wc0000gn/T/ipykernel_81567/3285557738.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['freq_cor'] = data.groupby('corrected').size()[data.corrected].values

# %%
suggs_error_token_x.head(2)
# Out:
#    index original corrected              filename  num_texts  length  \
# 0     10     belt     bellt  01-005-2-III-Eis.csv          0       4
# 1     17     kukt     kuckt  01-005-2-III-Eis.csv          0       4
#
#   start_position end_position  ct  \
# 0             46           50  10
# 1             80           84  17
#
#                                                                                                                                suggestions  \
# 0              [Belt, Welt, bald, hält, Geld, Feld, Held, Zelt, bebt, bellt, perlt, pell, best, meld, peilt, pellt, pult, zelt, bei, seit]
# 1  [rückt, zückt, bückt, guckt, kickt, kackt, gut, rückte, deckt, fügt, Lücke, lockt, weckt, packt, Mücke, kund, kürt, lügt, hackt, hockt]
#
#                rule_id  freq_ori  freq_cor  freq_tup
# 0  GERMAN_SPELLER_RULE        91       138        91
# 1  GERMAN_SPELLER_RULE        73       152        73

# %%
# Reset index
suggs_error_token_x.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Evaluation
# - Token
#     - lc
#     - cs
# - Before
#     - Get value counts
#     - Reset index
#     - Replace NaNs

# %%
suggs_error_token_x.suggestions.fillna(value='', inplace=True)

# %%
# TOKEN
token_eval_lc = litkey_2.evaluate(suggs_error_token_x)
token_eval_cs = litkey_2.evaluate(suggs_error_token_x, lower_case=False)
# Out:
#   0%|          | 0/24601 [00:00<?, ?it/s]
#   0%|          | 0/24601 [00:00<?, ?it/s]

# %%
token_eval_lc.shape[0] # 24601
token_eval_cs.shape[0] # 24601
# Out:
# 24601

# %%
token_eval_lc.head(2)
# Out:
#    index original corrected              filename  num_texts  length  \
# 0     10     belt     bellt  01-005-2-III-Eis.csv          0       4
# 1     17     kukt     kuckt  01-005-2-III-Eis.csv          0       4
#
#   start_position end_position  ct  \
# 0             46           50  10
# 1             80           84  17
#
#                                                                                                                                suggestions  \
# 0              [belt, welt, bald, hält, geld, feld, held, zelt, bebt, bellt, perlt, pell, best, meld, peilt, pellt, pult, zelt, bei, seit]
# 1  [rückt, zückt, bückt, guckt, kickt, kackt, gut, rückte, deckt, fügt, lücke, lockt, weckt, packt, mücke, kund, kürt, lügt, hackt, hockt]
#
#                rule_id  freq_ori  freq_cor  freq_tup in_sugg  sugg_idx   idx0
# 0  GERMAN_SPELLER_RULE        91       138        91    True       9.0  False
# 1  GERMAN_SPELLER_RULE        73       152        73   False       NaN  False

# %%
# EXPORT TOKEN
#token_eval_lc.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_lc.pkl')
#token_eval_cs.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_cs.pkl')

# %%
# Export pickle with ALL COLUMNS; ESP. OFFSETS
#token_eval_lc.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_lc_ALL_COLUMNS_OFFSETS.pkl')
#token_eval_lc.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_lc_ALL_COLUMNS_OFFSETS_OTHERINDEX_20211208.pkl')

# Export also for case sensitive; Language Tool with all text information
token_eval_cs.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_cs_ALL_COLUMNS_OFFSETS_OTHERINDEX_20211208.pkl')

# %%
# Export pickle with ALL COLUMNS; RULEID
#token_eval_lc.to_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_lc_ALL_COLUMNS_OFFSETS_RULEID.pkl')

# %% [markdown]
# ***

# %%
token_eval_lc = pd.read_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_lc.pkl')
token_eval_cs = pd.read_pickle('./pickles/pickles_evaluation/data_error_token_language_tool_whole_texts_evaluation_cs.pkl')

# %%
token_eval_lc[token_eval_lc.suggestions == ''].shape[0] # 11070
# Out:
# 5009

# %%
token_eval_lc.tail(10)
# Out:
#       original corrected             filename  \
# 24591    nieht     nicht  10-693-4-IV-Weg.csv
# 24592   vessen    fassen  10-693-4-IV-Weg.csv
# 24593  entlich   endlich  10-693-4-IV-Weg.csv
# 24594      tor       tür  10-693-4-IV-Weg.csv
# 24595   umarte   umarmte  10-693-4-IV-Weg.csv
# 24596    nieht     nicht  10-693-4-IV-Weg.csv
# 24597      ass        aß  10-693-4-IV-Weg.csv
# 24598   mutzte    nutzte  10-693-4-IV-Weg.csv
# 24599    momen    moment  10-693-4-IV-Weg.csv
# 24600  lutscha  lutscher  10-693-4-IV-Weg.csv
#
#                                                                                                                                                                                        suggestions  \
# 24591                                                    [nicht, sieht, zieht, niet, lieht, niest, liegt, geht, steht, dient, hielt, nichts, nie, nimmt, siehe, licht, sicht, dicht, dreht, liebt]
# 24592                               [dessen, hessen, festen, fassen, fressen, messen, essen, fesseln, wessen, pässen, fußen, bässen, säßen, fetzen, messen, nässen, fessel, kessen, mäßen, nässen]
# 24593  [endlich, endliche, entwich, entlieh, eidlich, ältlich, deutlich, südlich, westlich, englisch, etliche, seitlich, tödlich, zeitlich, amtlich, endlichen, entließ, entzog, rötlich, erblich]
# 24594
# 24595                                 [um arte, smarte, umarmte, umarme, karte, harte, malte, uralte, arte, klärte, marode, sparte, umbaute, zarte, quarte, matte, smart, starte, umarmen, umarmt]
# 24596                                                    [nicht, sieht, zieht, niet, lieht, niest, liegt, geht, steht, dient, hielt, nichts, nie, nimmt, siehe, licht, sicht, dicht, dreht, liebt]
# 24597                                                                                 [ass, aß, als, aus, dass, ans, saß, hass, fass, nass, bass, lass, pass, bass, pass, aßt, iss, äse, äst, des]
# 24598                             [musste, nutzte, müsste, nützte, mutete, bützte, motzte, münzte, putzte, setzte, letzte, mussten, müsse, nutzt, hütte, künste, meiste, müssten, nutzten, wusste]
# 24599                                               [mögen, domen, mimen, zoomen, nomen, boomen, namen, kamen, hohen, oben, polen, roman, hören, roten, zogen, boden, lösen, töten, böhmen, löwen]
# 24600                    [lutsch, luigi, lutsche, lunge, lutscht, putsch, kutsche, rutscht, ludger, lusaka, putsche, luchs, rutsche, luchse, rutsch, latsche, blutschau, datscha, dougga, hodscha]
#
#        freq_ori  freq_cor  freq_tup in_sugg  sugg_idx   idx0
# 24591         2       135         2    True       0.0   True
# 24592         1         2         1    True       3.0  False
# 24593        10        20        10    True       0.0   True
# 24594         1        15         1   False       NaN  False
# 24595         2        16         2    True       2.0  False
# 24596         2       135         2    True       0.0   True
# 24597         3         7         3    True       1.0  False
# 24598         1         1         1    True       1.0  False
# 24599         1         4         1   False       NaN  False
# 24600         8        56         8   False       NaN  False

# %%
token_eval_lc.tail(10)
# Out:
#         index original corrected             filename  num_texts  length  \
# 24591  210710    nieht     nicht  10-693-4-IV-Weg.csv       1921       5
# 24592  210711   vessen    fassen  10-693-4-IV-Weg.csv       1921       6
# 24593  210715  entlich   endlich  10-693-4-IV-Weg.csv       1921       7
# 24594  210730      tor       tür  10-693-4-IV-Weg.csv       1921       3
# 24595  210732   umarte   umarmte  10-693-4-IV-Weg.csv       1921       6
# 24596  210743    nieht     nicht  10-693-4-IV-Weg.csv       1921       5
# 24597  210749      ass        aß  10-693-4-IV-Weg.csv       1921       3
# 24598  210752   mutzte    nutzte  10-693-4-IV-Weg.csv       1921       6
# 24599  210754    momen    moment  10-693-4-IV-Weg.csv       1921       5
# 24600  210760  lutscha  lutscher  10-693-4-IV-Weg.csv       1921       7
#
#       start_position end_position   ct  \
# 24591            721          726  145
# 24592            727          733  146
# 24593            744          751  150
# 24594            820          823  165
# 24595            828          834  167
# 24596            886          891  178
# 24597            912          915  184
# 24598            923          929  187
# 24599            934          939  189
# 24600            962          969  195
#
#                                                                                                                                                                                        suggestions  \
# 24591                                                    [nicht, sieht, zieht, niet, lieht, niest, liegt, geht, steht, dient, hielt, nichts, nie, nimmt, siehe, licht, sicht, dicht, dreht, liebt]
# 24592                               [dessen, hessen, festen, fassen, fressen, messen, essen, fesseln, wessen, pässen, fußen, bässen, säßen, fetzen, messen, nässen, fessel, kessen, mäßen, nässen]
# 24593  [endlich, endliche, entwich, entlieh, eidlich, ältlich, deutlich, südlich, westlich, englisch, etliche, seitlich, tödlich, zeitlich, amtlich, endlichen, entließ, entzog, rötlich, erblich]
# 24594
# 24595                                 [um arte, smarte, umarmte, umarme, karte, harte, malte, uralte, arte, klärte, marode, sparte, umbaute, zarte, quarte, matte, smart, starte, umarmen, umarmt]
# 24596                                                    [nicht, sieht, zieht, niet, lieht, niest, liegt, geht, steht, dient, hielt, nichts, nie, nimmt, siehe, licht, sicht, dicht, dreht, liebt]
# 24597                                                                                 [ass, aß, als, aus, dass, ans, saß, hass, fass, nass, bass, lass, pass, bass, pass, aßt, iss, äse, äst, des]
# 24598                             [musste, nutzte, müsste, nützte, mutete, bützte, motzte, münzte, putzte, setzte, letzte, mussten, müsse, nutzt, hütte, künste, meiste, müssten, nutzten, wusste]
# 24599                                               [mögen, domen, mimen, zoomen, nomen, boomen, namen, kamen, hohen, oben, polen, roman, hören, roten, zogen, boden, lösen, töten, böhmen, löwen]
# 24600                    [lutsch, luigi, lutsche, lunge, lutscht, putsch, kutsche, rutscht, ludger, lusaka, putsche, luchs, rutsche, luchse, rutsch, latsche, blutschau, datscha, dougga, hodscha]
#
#                    rule_id  freq_ori  freq_cor  freq_tup in_sugg  sugg_idx  \
# 24591  GERMAN_SPELLER_RULE         2       135         2    True       0.0
# 24592  GERMAN_SPELLER_RULE         1         2         1    True       3.0
# 24593  GERMAN_SPELLER_RULE        10        20        10    True       0.0
# 24594                  NaN         1        15         1   False       NaN
# 24595  GERMAN_SPELLER_RULE         2        16         2    True       2.0
# 24596  GERMAN_SPELLER_RULE         2       135         2    True       0.0
# 24597  GERMAN_SPELLER_RULE         3         7         3    True       1.0
# 24598  GERMAN_SPELLER_RULE         1         1         1    True       1.0
# 24599  GERMAN_SPELLER_RULE         1         4         1   False       NaN
# 24600  GERMAN_SPELLER_RULE         8        56         8   False       NaN
#
#         idx0
# 24591   True
# 24592  False
# 24593   True
# 24594  False
# 24595  False
# 24596   True
# 24597  False
# 24598  False
# 24599  False
# 24600  False
